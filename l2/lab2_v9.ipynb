# %% [markdown]
# 1. Завантажити та попередньо обробити дані твітів за допомогою функції process_tweet.

# %%
import nltk
nltk.download("twitter_samples")
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Unzipping corpora/twitter_samples.zip.
# True

# %%
from nltk.corpus import twitter_samples
import numpy as np

# %%
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import re
import string

from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

# %%
def process_tweet(tweet):
    '''
    Input:
        tweet: a string containing a tweet
    Output:
        tweets_clean: a list of words containing the processed tweet

    '''
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    # remove stock market tickers like $GE
    tweet = re.sub(r'\$\w*', '', tweet)
    # remove old style retweet text "RT"
    tweet = re.sub(r'^RT[\s]+', '', tweet)
    # remove hyperlinks
    #tweet = re.sub(r'https?:\/\/.*[\r\n]*', '', tweet)
    tweet = re.sub(r'https?://[^\s\n\r]+', '', tweet)
    # remove hashtags
    # only removing the hash # sign from the word
    tweet = re.sub(r'#', '', tweet)
    # tokenize tweets
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,
                               reduce_len=True)
    tweet_tokens = tokenizer.tokenize(tweet)

    tweets_clean = []
    for word in tweet_tokens:
        if (word not in stopwords_english and  # remove stopwords
                word not in string.punctuation):  # remove punctuation
            # tweets_clean.append(word)
            stem_word = stemmer.stem(word)  # stemming word
            tweets_clean.append(stem_word)

    return tweets_clean

# %% [markdown]
# 2. Побудувати словник частотності слів для позитивного і негативного класів.

# %%
def count_tweets(result, tweets, ys):
    for y, tweet in zip(ys, tweets):
        for word in process_tweet(tweet):
            pair = (word, y)

            if pair in result:
                result[pair] += 1
            else:
                result[pair] = 1

    return result

# %%
freqs = count_tweets({}, train_x, train_y)

# %%
freqs[('fuck', 1)]
# Out:
# 20

# %%
freqs[('fuck', 0)]
# Out:
# 47

# %%
len(freqs)
# Out:
# 11397

# %% [markdown]
# 3. Обчислити логарифмічні апріорні ймовірності (log prior) для кожного класу.
#
# Алгоритм:
# - Порахувати кількість унікальних слів V.
# - Порахувати загальну кількість позитивних слів N_pos і негативних слів N_neg.
# - Порахувати кількість документів D.
# - Порахувати кількість позитивних документів D_pos і негативних документів D_neg.
# - Обчислити log prior:
#     logprior = log(D_pos) - log(D_neg)
# - Для кожного слова у словнику:
#     - Дістати частотності слова для позитивного і негативного класів.
#     - Обчислити ймовірності слова для кожного класу з лапласівським згладжуванням:
#         p_w_pos = (freq_pos + 1) / (N_pos + V)
#         p_w_neg = (freq_neg + 1) / (N_neg + V)
#     - Обчислити log likelihood як логарифм відношення ймовірностей:
#         loglikelihood = log(p_w_pos / p_w_neg)
#
# Можлива реалізація:
#
# 4. Обчислити логарифмічні правдоподібності (log likelihood) для кожного слова і класу.

# %%
def train_naive_bayes(freqs, train_x, train_y):
    loglikelihood = {}
    logprior = 0

    vocab = set([pair[0] for pair in freqs.keys()])
    V = len(vocab)

    N_pos = N_neg = 0
    for pair in freqs.keys():
        if pair[1] > 0:
            N_pos += freqs[pair]
        else:
            N_neg += freqs[pair]

    D = len(train_y)
    D_pos = sum(train_y)
    D_neg = D - D_pos

    logprior = np.log(D_pos) - np.log(D_neg)

    for word in vocab:
        freq_pos = freqs.get((word, 1), 0)
        freq_neg = freqs.get((word, 0), 0)

        p_w_pos = (freq_pos + 1) / (N_pos + V)
        p_w_neg = (freq_neg + 1) / (N_neg + V)

        loglikelihood[word] = np.log(p_w_pos) - np.log(p_w_neg)

    return logprior, loglikelihood

# %%
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)

# %%
logprior
# Out:
# np.float64(0.0)

# %%
loglikelihood
# Out:
# {'hah': np.float64(0.6787947231732101),
#  '61': np.float64(-0.7074996379466807),
#  'episod': np.float64(-0.5251780811527276),
#  'jai': np.float64(-0.014352457386735296),
#  'paralyz': np.float64(0.6787947231732101),
#  'epic': np.float64(-0.014352457386735296),
#  'diva': np.float64(0.6787947231732101),
#  'noseble': np.float64(-0.7074996379466807),
#  'oliv': np.float64(0.6787947231732101),
#  'knw': np.float64(-0.014352457386735296),
#  '150': np.float64(0.6787947231732101),
#  'airport': np.float64(-0.9951817103984624),
#  'foood': np.float64(-0.7074996379466807),
#  'gosh': np.float64(-0.5251780811527276),
#  'raheel': np.float64(0.6787947231732101),
#  'ngeze': np.float64(-0.7074996379466807),
#  'islamist': np.float64(0.6787947231732101),
#  'notic': np.float64(-0.5449807084489064),
#  'charg': np.float64(-0.302034529838517),
#  'myungsoo': np.float64(-0.7074996379466807),
#  'cranium': np.float64(0.6787947231732101),
#  'custom': np.float64(0.9019382744874189),
#  'iran': np.float64(-0.7074996379466807),
#  'dentist': np.float64(-1.1129647460548462),
#  'mar': np.float64(0.6787947231732101),
#  'contempl': np.float64(0.6787947231732101),
#  "friday'": np.float64(-0.014352457386735296),
#  'siguro': np.float64(0.6787947231732101),
#  'dosent': np.float64(-0.7074996379466807),
#  'tranc': np.float64(0.6787947231732101),
#  'anywayhedidanicejob': np.float64(-0.7074996379466807),
#  'leannerin': np.float64(-0.014352457386735296),
#  'jelous': np.float64(-0.7074996379466807),
#  '💟': np.float64(1.0842598312813738),
#  '⭐': np.float64(1.3719419037331555),
#  'anxiou': np.float64(-0.014352457386735296),
#  'gensan': np.float64(0.6787947231732101),
#  'must': np.float64(0.12874838625393803),
#  'loiyal': np.float64(0.6787947231732101),
#  'otwol': np.float64(0.6787947231732101),
#  '22': np.float64(-0.014352457386737072),
#  'roommat': np.float64(-0.7074996379466807),
#  'afternoon': np.float64(0.96647679562499),
#  'taybigail': np.float64(-0.7074996379466807),
#  'backflip': np.float64(1.0842598312813738),
#  'unlock': np.float64(0.6787947231732101),
#  'nje': np.float64(-0.7074996379466807),
#  'chronicl': np.float64(1.3719419037331555),
#  'given': np.float64(0.6787947231732101),
#  '10:16': np.float64(0.6787947231732101),
#  'promis': np.float64(0.20879109392747353),
#  'leav': np.float64(-0.9151390027249251),
#  'koel': np.float64(0.6787947231732101),
#  'matsu_bouzu': np.float64(0.6787947231732101),
#  'caribbean': np.float64(-0.7074996379466807),
#  'shouldeeerr': np.float64(-0.7074996379466807),
#  '50.000': np.float64(1.3719419037331555),
#  '—': np.float64(0.17670277937597323),
#  'gooo': np.float64(-0.014352457386735296),
#  'ifimeetanalien': np.float64(0.6787947231732101),
#  'toler': np.float64(-0.7074996379466807),
#  'activ': np.float64(-0.8616503177739396),
#  'cider': np.float64(0.6787947231732101),
#  'greska': np.float64(-0.7074996379466807),
#  'instant': np.float64(-0.014352457386735296),
#  'tuna': np.float64(0.6787947231732101),
#  'ako': np.float64(-0.014352457386735296),
#  'daili': np.float64(-0.014352457386737072),
#  'abi': np.float64(-0.7074996379466807),
#  'lone': np.float64(-2.0937939990665715),
#  'banana': np.float64(-0.9306431892608913),
#  'nc': np.float64(1.0842598312813738),
#  'dalla': np.float64(-1.400646818506626),
#  'auto-followback': np.float64(-0.7074996379466807),
#  'georg': np.float64(-0.7074996379466807),
#  'maa': np.float64(-1.1129647460548462),
#  'place': np.float64(0.5117406385100436),
#  'kahlil': np.float64(0.6787947231732101),
#  'buddi': np.float64(0.96647679562499),
#  'da': np.float64(-0.19667401418069197),
#  'fave': np.float64(1.3719419037331555),
#  'chariti': np.float64(0.6787947231732101),
#  'contractu': np.float64(0.6787947231732101),
#  'pict': np.float64(-0.014352457386735296),
#  'minkyuk': np.float64(-0.7074996379466807),
#  'bluejay': np.float64(0.6787947231732101),
#  'crei': np.float64(-0.7074996379466807),
#  'outsid': np.float64(-0.8252826736030645),
#  '510': np.float64(-0.7074996379466807),
#  'rakyat': np.float64(0.6787947231732101),
#  'bitchfac': np.float64(0.6787947231732101),
#  'movi': np.float64(-0.014352457386736184),
#  'attempt': np.float64(-0.014352457386735296),
#  'ughh': np.float64(-0.7074996379466807),
#  'diet': np.float64(-0.014352457386735296),
#  'ugh': np.float64(-2.499259107174736),
#  'np': np.float64(0.6787947231732101),
#  'mwa': np.float64(-0.7074996379466807),
#  'frnd': np.float64(0.6787947231732101),
#  'superdri': np.float64(0.6787947231732101),
#  'ayemso': np.float64(-0.7074996379466807),
#  'extraordinari': np.float64(0.6787947231732101),
#  'defens': np.float64(-0.7074996379466807),
#  'entlead': np.float64(-0.7074996379466807),
#  'pabeb': np.float64(-1.1129647460548462),
#  'fire': np.float64(-0.014352457386735296),
#  'curri': np.float64(1.0842598312813738),
#  'junjou': np.float64(-1.1129647460548462),
#  'describ': np.float64(-0.7074996379466807),
#  '@connorfranta': np.float64(0.6787947231732101),
#  'sudden': np.float64(-1.6237903698208367),
#  'billi': np.float64(1.0842598312813738),
#  'berangkaat': np.float64(0.6787947231732101),
#  'karin': np.float64(-0.7074996379466807),
#  'yipppi': np.float64(0.6787947231732101),
#  'oracl': np.float64(0.6787947231732101),
#  'kamaal': np.float64(0.6787947231732101),
#  'sizw': np.float64(-0.7074996379466807),
#  'paddock': np.float64(0.6787947231732101),
#  'laugh': np.float64(-0.16850313721399424),
#  '👏': np.float64(1.3719419037331555),
#  'blackfli': np.float64(0.6787947231732101),
#  'north': np.float64(-0.7074996379466807),
#  'gameplay': np.float64(0.6787947231732101),
#  'interraci': np.float64(-0.7074996379466807),
#  'dipsatch': np.float64(0.6787947231732101),
#  'famou': np.float64(-0.9306431892608913),
#  '’': np.float64(-0.21502315284888684),
#  'thanksss': np.float64(-0.014352457386735296),
#  'whoop': np.float64(1.5950854550473643),
#  'loveofmylif': np.float64(-0.7074996379466807),
#  'power': np.float64(0.13979822244052187),
#  'band': np.float64(-0.014352457386737072),
#  'jamie-le': np.float64(0.6787947231732101),
#  'consist': np.float64(0.6787947231732101),
#  'wae': np.float64(-0.7074996379466807),
#  'hotscratch': np.float64(-0.7074996379466807),
#  'whay': np.float64(-0.7074996379466807),
#  'pipe': np.float64(-0.7074996379466807),
#  'fe14': np.float64(-0.7074996379466807),
#  'roof': np.float64(-0.4198175654949008),
#  'crime': np.float64(-0.7074996379466807),
#  'chau': np.float64(0.6787947231732101),
#  'advic': np.float64(1.9315576916685782),
#  'clark': np.float64(-0.014352457386735296),
#  'choreograph': np.float64(-0.7074996379466807),
#  'scienc': np.float64(1.0842598312813738),
#  'yūjō-cosplay': np.float64(0.6787947231732101),
#  'bp': np.float64(-0.014352457386735296),
#  'collar': np.float64(-0.7074996379466807),
#  'morn': np.float64(1.0417002168625782),
#  'rted': np.float64(-0.4198175654949008),
#  'effin': np.float64(-0.7074996379466807),
#  'hih': np.float64(0.6787947231732101),
#  'seo': np.float64(-0.7074996379466807),
#  'mjhe': np.float64(-1.1129647460548462),
#  'm5m6junction': np.float64(-0.7074996379466807),
#  'burek': np.float64(0.6787947231732101),
#  'routt': np.float64(0.6787947231732101),
#  'accnt': np.float64(1.0842598312813738),
#  'wow': np.float64(1.0842598312813738),
#  'pose': np.float64(1.0842598312813738),
#  'slovenia': np.float64(1.0842598312813738),
#  'empow': np.float64(0.6787947231732101),
#  'manbearpig': np.float64(-0.7074996379466807),
#  '😍': np.float64(0.6787947231732101),
#  'mamabear': np.float64(-0.7074996379466807),
#  'matthew': np.float64(-0.014352457386735296),
#  'midori': np.float64(-0.7074996379466807),
#  'charlott': np.float64(0.6787947231732101),
#  'wound': np.float64(-0.7074996379466807),
#  'sexyjan': np.float64(-0.7074996379466807),
#  'uu': np.float64(-0.4198175654949008),
#  'cumbria': np.float64(0.6787947231732101),
#  'panic': np.float64(-0.7074996379466807),
#  "yesterday'": np.float64(-0.014352457386735296),
#  'overnight': np.float64(0.6787947231732101),
#  'kaussi': np.float64(-0.7074996379466807),
#  '1tb': np.float64(0.6787947231732101),
#  'zaz': np.float64(-0.7074996379466807),
#  'gelen': np.float64(0.6787947231732101),
#  'sky': np.float64(1.0842598312813738),
#  'newblogpost': np.float64(0.6787947231732101),
#  'credit': np.float64(0.20879109392747353),
#  'mustread': np.float64(0.6787947231732101),
#  'nhl': np.float64(-0.7074996379466807),
#  'pinkfinit': np.float64(-0.7074996379466807),
#  'constant': np.float64(0.6787947231732101),
#  'nixu': np.float64(0.6787947231732101),
#  'hop': np.float64(-0.7074996379466807),
#  'mohapatra': np.float64(0.6787947231732101),
#  'teamnatur': np.float64(0.6787947231732101),
#  'organ': np.float64(-0.4198175654949008),
#  'ffback': np.float64(1.0842598312813738),
#  'golf': np.float64(-0.7074996379466807),
#  'chswiyfxcskcalum': np.float64(-0.7074996379466807),
#  'couldnt': np.float64(0.6787947231732101),
#  'pake': np.float64(0.6787947231732101),
#  '9:15': np.float64(-0.7074996379466807),
#  'a9': np.float64(-1.1129647460548462),
#  'elah': np.float64(0.6787947231732101),
#  'obamainkenya': np.float64(0.6787947231732101),
#  'homegirl': np.float64(0.6787947231732101),
#  'lage': np.float64(-0.7074996379466807),
#  'bittersweet': np.float64(-0.7074996379466807),
#  'scoup': np.float64(-1.1129647460548462),
#  'ta': np.float64(-0.014352457386735296),
#  'twitlong': np.float64(0.6787947231732101),
#  'exist': np.float64(-0.4198175654949008),
#  'redecor': np.float64(0.6787947231732101),
#  'njoy': np.float64(0.6787947231732101),
#  'shek': np.float64(-0.7074996379466807),
#  'arnd': np.float64(0.6787947231732101),
#  'nba': np.float64(1.5950854550473643),
#  'faggot': np.float64(-0.7074996379466807),
#  'besst': np.float64(-0.7074996379466807),
#  'wiw': np.float64(0.6787947231732101),
#  '0345': np.float64(1.0842598312813738),
#  'tough': np.float64(-0.014352457386737072),
#  'awel': np.float64(-0.7074996379466807),
#  'humid': np.float64(0.6787947231732101),
#  'henc': np.float64(0.6787947231732101),
#  'earlob': np.float64(-0.7074996379466807),
#  'abus': np.float64(-0.7074996379466807),
#  'a5': np.float64(0.6787947231732101),
#  'net': np.float64(-0.4198175654949008),
#  'gap': np.float64(-0.7074996379466807),
#  'slower': np.float64(0.6787947231732101),
#  '▪': np.float64(1.0842598312813738),
#  'hunger': np.float64(0.6787947231732101),
#  'andi': np.float64(0.3911126507214284),
#  '823': np.float64(-0.7074996379466807),
#  'side': np.float64(0.6787947231732101),
#  'smthng': np.float64(1.0842598312813738),
#  'pak': np.float64(-0.9306431892608913),
#  'adventur': np.float64(0.9019382744874189),
#  "m'ladi": np.float64(-0.7074996379466807),
#  'websit': np.float64(0.11917893523778744),
#  '320': np.float64(-0.7074996379466807),
#  'pa': np.float64(-1.51842985416301),
#  '75x': np.float64(0.6787947231732101),
#  'goodwynsgoodi': np.float64(0.6787947231732101),
#  'bitti': np.float64(1.0842598312813738),
#  'photoset': np.float64(1.3719419037331555),
#  'concern': np.float64(-0.4198175654949008),
#  'procedur': np.float64(0.6787947231732101),
#  'braid': np.float64(-1.1129647460548462),
#  'razzist': np.float64(-0.7074996379466807),
#  'cajun': np.float64(0.6787947231732101),
#  'tak': np.float64(-0.4198175654949008),
#  '4th': np.float64(0.9019382744874189),
#  'torn': np.float64(-0.7074996379466807),
#  'boner': np.float64(-0.7074996379466807),
#  'french': np.float64(0.4964731663792534),
#  'written': np.float64(-1.1129647460548462),
#  'jiba': np.float64(0.6787947231732101),
#  'max': np.float64(-0.4198175654949008),
#  'poppin': np.float64(-0.7074996379466807),
#  'particularli': np.float64(1.0842598312813738),
#  'weight': np.float64(1.7774070118413192),
#  'iplay': np.float64(0.6787947231732101),
#  'sara': np.float64(-1.1129647460548462),
#  'kadhafi': np.float64(-0.7074996379466807),
#  'omgg': np.float64(0.6787947231732101),
#  'zone': np.float64(-0.7074996379466807),
#  'riski': np.float64(-0.7074996379466807),
#  'geekiest': np.float64(0.6787947231732101),
#  'x16': np.float64(0.6787947231732101),
#  'channel': np.float64(-0.014352457386737072),
#  'whatthefuck': np.float64(-0.7074996379466807),
#  'lighter': np.float64(0.6787947231732101),
#  'fruit': np.float64(0.4964731663792534),
#  'transfer': np.float64(-1.400646818506626),
#  'mess': np.float64(-1.6237903698208367),
#  '😒': np.float64(-0.302034529838517),
#  'mcflurri': np.float64(-0.7074996379466807),
#  'orcalov': np.float64(-0.7074996379466807),
#  'contribut': np.float64(1.0842598312813738),
#  'laiten': np.float64(0.6787947231732101),
#  'steve': np.float64(1.0842598312813738),
#  'tita': np.float64(-0.7074996379466807),
#  'rubber': np.float64(1.3719419037331555),
#  "schedule'": np.float64(-0.7074996379466807),
#  'paid': np.float64(-2.2115770347229553),
#  'annual': np.float64(0.6787947231732101),
#  '78x': np.float64(0.6787947231732101),
#  'aspect': np.float64(0.6787947231732101),
#  'looong': np.float64(-0.7074996379466807),
#  'yorkshir': np.float64(1.0842598312813738),
#  'whhr': np.float64(-0.7074996379466807),
#  'nowt': np.float64(-0.7074996379466807),
#  'stayfresh': np.float64(0.6787947231732101),
#  'old': np.float64(-0.014352457386735296),
#  'setter': np.float64(-0.7074996379466807),
#  'sheep': np.float64(-0.014352457386735296),
#  "doido'": np.float64(0.6787947231732101),
#  'coca': np.float64(0.6787947231732101),
#  'ndee': np.float64(0.6787947231732101),
#  'supris': np.float64(0.6787947231732101),
#  'newest': np.float64(0.6787947231732101),
#  '30th': np.float64(-0.014352457386735296),
#  '500': np.float64(0.3911126507214284),
#  'fightstickfriday': np.float64(0.6787947231732101),
#  '4:20': np.float64(-0.7074996379466807),
#  'stocko': np.float64(-0.7074996379466807),
#  'happend': np.float64(-0.7074996379466807),
#  '777x': np.float64(0.6787947231732101),
#  'node': np.float64(-0.7074996379466807),
#  'tub': np.float64(-0.7074996379466807),
#  'yeyi': np.float64(-0.7074996379466807),
#  'vaw': np.float64(-0.7074996379466807),
#  'anymoree': np.float64(-0.7074996379466807),
#  "cupid'": np.float64(-0.7074996379466807),
#  'yield': np.float64(-0.7074996379466807),
#  'charismat': np.float64(0.6787947231732101),
#  'candi': np.float64(-0.014352457386737072),
#  '697': np.float64(-0.7074996379466807),
#  'marino': np.float64(-0.7074996379466807),
#  'sulk': np.float64(-0.7074996379466807),
#  'countdown': np.float64(-0.7074996379466807),
#  'yournaturallead': np.float64(0.6787947231732101),
#  'milf': np.float64(-0.7074996379466807),
#  'rememb': np.float64(-0.19667401418069197),
#  '31st': np.float64(0.3911126507214284),
#  'penyfan': np.float64(-0.7074996379466807),
#  'addict': np.float64(1.3719419037331555),
#  'andal': np.float64(0.6787947231732101),
#  'airlin': np.float64(0.6787947231732101),
#  'turn': np.float64(0.05464041410021636),
#  'stan': np.float64(-0.014352457386735296),
#  'slip': np.float64(0.6787947231732101),
#  'fingers-cross': np.float64(0.6787947231732101),
#  'hubbi': np.float64(-0.014352457386735296),
#  'yeeeyyy': np.float64(0.6787947231732101),
#  'brake': np.float64(-0.7074996379466807),
#  'minecon': np.float64(-0.7074996379466807),
#  'haha': np.float64(0.5734342075153833),
#  'bday': np.float64(0.7965777588295939),
#  'triathlet': np.float64(0.6787947231732101),
#  'seafood': np.float64(0.6787947231732101),
#  'popsicl': np.float64(0.6787947231732101),
#  'chef': np.float64(0.6787947231732101),
#  'dudett': np.float64(0.6787947231732101),
#  'jonghyun': np.float64(-0.014352457386735296),
#  'wit': np.float64(0.3911126507214284),
#  'evelineconrad': np.float64(-0.7074996379466807),
#  'spag': np.float64(0.6787947231732101),
#  'fridayfreebi': np.float64(0.6787947231732101),
#  'muna': np.float64(0.6787947231732101),
#  'hen': np.float64(-0.7074996379466807),
#  'godbless': np.float64(1.0842598312813738),
#  'navig': np.float64(0.6787947231732101),
#  'easier': np.float64(-0.302034529838517),
#  'anythin': np.float64(-0.7074996379466807),
#  'motilium': np.float64(-0.7074996379466807),
#  'ux': np.float64(0.6787947231732101),
#  'law': np.float64(-0.5251780811527276),
#  'pech': np.float64(0.6787947231732101),
#  'encor': np.float64(-1.6237903698208367),
#  'pigeon': np.float64(-0.7074996379466807),
#  'creta': np.float64(0.6787947231732101),
#  'doesnt': np.float64(0.6787947231732083),
#  '💜': np.float64(-0.014352457386735296),
#  'cag': np.float64(-0.7074996379466807),
#  'wont': np.float64(-0.8252826736030645),
#  'racist': np.float64(0.6787947231732101),
#  'aaaand': np.float64(0.6787947231732101),
#  'mubark': np.float64(-0.7074996379466807),
#  'encompass': np.float64(0.6787947231732101),
#  'hogo': np.float64(-0.7074996379466807),
#  'pretend': np.float64(1.0842598312813738),
#  'abit': np.float64(0.6787947231732101),
#  'streak': np.float64(-0.7074996379466807),
#  'potenti': np.float64(0.6787947231732101),
#  'bugatti': np.float64(0.6787947231732101),
#  'victori': np.float64(-0.7074996379466807),
#  'battlefield': np.float64(0.6787947231732101),
#  'mino': np.float64(-1.1129647460548462),
#  'vid': np.float64(2.1828721199494847),
#  '🐑': np.float64(0.6787947231732101),
#  'lah': np.float64(-0.4198175654949008),
#  'ikea': np.float64(-0.7074996379466807),
#  'stress': np.float64(-0.7074996379466825),
#  'winner': np.float64(1.3719419037331555),
#  'kian': np.float64(-1.400646818506626),
#  'baloch': np.float64(0.6787947231732101),
#  'ay': np.float64(-0.7074996379466807),
#  'wsj': np.float64(-1.1129647460548462),
#  'prey': np.float64(-0.7074996379466807),
#  'three': np.float64(0.23696197089417126),
#  '2/3': np.float64(-1.1129647460548462),
#  'sweeeti': np.float64(0.6787947231732101),
#  'basara': np.float64(-0.7074996379466807),
#  'tasteless': np.float64(-0.7074996379466807),
#  'waaa': np.float64(-0.7074996379466807),
#  'landscap': np.float64(1.0842598312813738),
#  'jazmin': np.float64(1.3719419037331555),
#  'x18': np.float64(0.6787947231732101),
#  'idol': np.float64(0.2733296150650446),
#  '╭': np.float64(1.5950854550473643),
#  'dollar': np.float64(-0.7074996379466807),
#  'offlin': np.float64(-0.014352457386735296),
#  'hyung': np.float64(-0.7074996379466807),
#  'afghanistn': np.float64(-0.7074996379466807),
#  'basenam': np.float64(-0.7074996379466807),
#  'unfollow': np.float64(1.7774070118413192),
#  'normal': np.float64(-0.014352457386737072),
#  'junior': np.float64(1.0842598312813738),
#  'rakhi': np.float64(0.6787947231732101),
#  'custard': np.float64(0.6787947231732101),
#  "j'": np.float64(0.6787947231732101),
#  'chip': np.float64(1.0842598312813738),
#  'gotham': np.float64(0.6787947231732101),
#  '👯': np.float64(0.6787947231732101),
#  'convers': np.float64(-0.014352457386735296),
#  'sofa': np.float64(0.6787947231732101),
#  'bye': np.float64(-0.16850313721399424),
#  'halaaang': np.float64(-0.7074996379466807),
#  'rib': np.float64(0.3911126507214284),
#  'region': np.float64(-0.014352457386737072),
#  'beb': np.float64(-0.7074996379466807),
#  'woman': np.float64(-0.4198175654949008),
#  'auguri': np.float64(0.6787947231732101),
#  'potag': np.float64(-0.7074996379466807),
#  'incred': np.float64(1.7774070118413192),
#  'oth': np.float64(0.6787947231732101),
#  'kikmeguy': np.float64(-0.7074996379466825),
#  'photo': np.float64(0.3339542368814792),
#  'hyper': np.float64(-1.1129647460548462),
#  'gay': np.float64(-0.573968245322158),
#  'atp': np.float64(1.0842598312813738),
#  'appa': np.float64(0.6787947231732101),
#  '️2': np.float64(-0.7074996379466807),
#  'posti': np.float64(-0.7074996379466807),
#  'swearword': np.float64(0.6787947231732101),
#  'offer': np.float64(-0.2374960087009459),
#  'gail': np.float64(0.6787947231732101),
#  'gamestomp': np.float64(-0.7074996379466807),
#  'deplet': np.float64(-0.7074996379466807),
#  'llama': np.float64(-0.7074996379466807),
#  'biphob': np.float64(-1.1129647460548462),
#  'clown': np.float64(-1.1129647460548462),
#  'mi': np.float64(0.4964731663792534),
#  'himseek': np.float64(-0.7074996379466807),
#  'term': np.float64(0.3911126507214284),
#  'reach': np.float64(-0.7074996379466807),
#  '–': np.float64(2.00055056315553),
#  'loss': np.float64(-1.400646818506626),
#  'putovanja': np.float64(0.6787947231732101),
#  '2-3': np.float64(-0.014352457386735296),
#  'dh': np.float64(-1.1129647460548462),
#  'nick': np.float64(0.6787947231732101),
#  'handshom': np.float64(0.6787947231732101),
#  'lace': np.float64(-0.7074996379466807),
#  'bani': np.float64(-1.1129647460548462),
#  'swag': np.float64(-0.014352457386735296),
#  'semo': np.float64(1.0842598312813738),
#  'finnigan': np.float64(0.6787947231732101),
#  'pre-holiday': np.float64(-0.7074996379466807),
#  '15ml': np.float64(0.6787947231732101),
#  'workinprogress': np.float64(0.6787947231732101),
#  'wet': np.float64(-1.3136354415169968),
#  'marri': np.float64(0.3911126507214284),
#  'dinooo': np.float64(0.6787947231732101),
#  'tricki': np.float64(-0.7074996379466807),
#  'fml': np.float64(-1.400646818506626),
#  '60': np.float64(0.6787947231732101),
#  'aich': np.float64(0.6787947231732101),
#  'expir': np.float64(-1.1129647460548462),
#  'thur': np.float64(1.0842598312813738),
#  '☆': np.float64(1.3719419037331555),
#  '👌': np.float64(-0.014352457386735296),
#  'cement': np.float64(-0.7074996379466807),
#  'rocket': np.float64(0.6787947231732101),
#  'heath': np.float64(-1.1129647460548462),
#  'surpris': np.float64(0.5917833461835791),
#  'wasp': np.float64(-1.1129647460548462),
#  'selo': np.float64(0.6787947231732101),
#  'warlock': np.float64(0.6787947231732101),
#  'buri': np.float64(-0.7074996379466807),
#  'kikmeboy': np.float64(-0.014352457386735296),
#  'twice': np.float64(-0.4198175654949008),
#  'a6': np.float64(0.6787947231732101),
#  'badass': np.float64(0.6787947231732101),
#  'immigr': np.float64(0.6787947231732101),
#  'te': np.float64(-0.7074996379466807),
#  'ventur': np.float64(0.6787947231732101),
#  'entir': np.float64(-0.7074996379466825),
#  'mobil': np.float64(0.2733296150650446),
#  'igbo': np.float64(-0.7074996379466807),
#  'boot': np.float64(-0.302034529838517),
#  'land': np.float64(1.0842598312813738),
#  'starsquad': np.float64(1.3719419037331555),
#  'yippee': np.float64(0.6787947231732101),
#  'cwnt': np.float64(-0.7074996379466807),
#  'wait': np.float64(0.40008132070418956),
#  'smile': np.float64(1.5542634605271086),
#  'derek': np.float64(-0.7074996379466807),
#  'gf': np.float64(-0.014352457386737072),
#  'hungrrryyi': np.float64(-0.7074996379466807),
#  'away': np.float64(-0.664940023527886),
#  'dreamer': np.float64(0.6787947231732101),
#  'mare': np.float64(-0.7074996379466807),
#  'misplac': np.float64(-0.7074996379466807),
#  'deck': np.float64(-0.7074996379466807),
#  'yep': np.float64(0.2733296150650446),
#  'omfg': np.float64(-1.1129647460548462),
#  'housem': np.float64(0.6787947231732101),
#  'presid': np.float64(1.0842598312813738),
#  'syria': np.float64(-1.1129647460548462),
#  'felt': np.float64(-0.2374960087009459),
#  'sweet': np.float64(1.0271014174414246),
#  'jungl': np.float64(0.6787947231732101),
#  'rider': np.float64(-0.7074996379466807),
#  'minc': np.float64(-0.7074996379466807),
#  'roseburi': np.float64(-0.7074996379466807),
#  'narrow-mind': np.float64(0.6787947231732101),
#  'ifc': np.float64(0.6787947231732101),
#  'deleg': np.float64(0.6787947231732101),
#  'gig': np.float64(-0.7074996379466807),
#  'snob': np.float64(-0.7074996379466807),
#  'ig': np.float64(1.3719419037331555),
#  'nsfw': np.float64(-0.014352457386735296),
#  '2hr': np.float64(-0.7074996379466807),
#  'lsceen': np.float64(0.6787947231732101),
#  'sens': np.float64(1.9315576916685782),
#  'prettiest': np.float64(0.6787947231732101),
#  'lahat': np.float64(-0.7074996379466807),
#  'proud': np.float64(0.2733296150650446),
#  'slowli': np.float64(-0.7074996379466807),
#  'broadcast': np.float64(-1.2671154258821034),
#  'chan': np.float64(0.6787947231732101),
#  'chart': np.float64(-1.1129647460548462),
#  'shake': np.float64(0.3911126507214284),
#  'briefli': np.float64(-0.7074996379466807),
#  'fantasi': np.float64(1.0842598312813738),
#  'kia': np.float64(-0.014352457386735296),
#  'unknown': np.float64(-0.4198175654949008),
#  'insomnia': np.float64(0.6787947231732101),
#  'tryna': np.float64(-0.7074996379466807),
#  '15-24': np.float64(-0.7074996379466807),
#  'iren': np.float64(-1.1129647460548462),
#  'couldv': np.float64(-0.7074996379466807),
#  'protein': np.float64(-0.7074996379466807),
#  'deya': np.float64(0.6787947231732101),
#  'brother': np.float64(-0.9306431892608913),
#  'folk': np.float64(1.3719419037331555),
#  'tote': np.float64(-0.7074996379466807),
#  'mayhem': np.float64(0.6787947231732101),
#  'nigeria': np.float64(0.6787947231732101),
#  'us': np.float64(0.9768395826605367),
#  'x7': np.float64(0.6787947231732101),
#  'sinaloa': np.float64(0.6787947231732101),
#  'subway': np.float64(-0.7074996379466807),
#  'rate': np.float64(-0.7074996379466807),
#  'trailblazerhonor': np.float64(0.6787947231732101),
#  'justiceforsandrabland': np.float64(-1.1129647460548462),
#  'tango': np.float64(0.6787947231732101),
#  'vscocousin': np.float64(0.6787947231732101),
#  'afternon': np.float64(0.6787947231732101),
#  'copi': np.float64(0.9019382744874189),
#  'morocco': np.float64(0.6787947231732101),
#  '1pm': np.float64(-0.7074996379466807),
#  'warm': np.float64(0.20879109392747353),
#  'rick': np.float64(-0.7074996379466807),
#  'pump': np.float64(0.3911126507214284),
#  'randi': np.float64(0.6787947231732101),
#  'nj': np.float64(0.6787947231732101),
#  'norh': np.float64(0.6787947231732101),
#  'briliant': np.float64(0.6787947231732101),
#  'reina': np.float64(0.6787947231732101),
#  'avi': np.float64(-0.4198175654949008),
#  'melatonin': np.float64(-0.7074996379466807),
#  'tenyai': np.float64(0.6787947231732101),
#  'wayanadan': np.float64(0.6787947231732101),
#  'bit': np.float64(0.2539115292079437),
#  '.\n.': np.float64(-1.1129647460548462),
#  'yello': np.float64(0.6787947231732101),
#  'über': np.float64(-0.7074996379466807),
#  'okok': np.float64(0.6787947231732101),
#  'judgment': np.float64(0.6787947231732101),
#  'thankyouuu': np.float64(0.6787947231732101),
#  'swan': np.float64(-0.014352457386735296),
#  'shortli': np.float64(-0.014352457386735296),
#  '350': np.float64(-0.7074996379466807),
#  'somehow': np.float64(-1.1129647460548462),
#  'air': np.float64(0.96647679562499),
#  'foot': np.float64(-1.6237903698208367),
#  "michael'": np.float64(-0.7074996379466807),
#  'suppl': np.float64(-0.7074996379466807),
#  'cold': np.float64(-1.9602626064420487),
#  'mad': np.float64(-0.8252826736030645),
#  'granni': np.float64(0.6787947231732101),
#  'smooth': np.float64(-0.7074996379466807),
#  'six': np.float64(0.6787947231732101),
#  'read': np.float64(0.5803546503599577),
#  'tomorrowland': np.float64(0.6787947231732101),
#  'welcoma.hav': np.float64(0.6787947231732101),
#  'anybodi': np.float64(-2.0937939990665715),
#  'unfriend': np.float64(-0.7074996379466807),
#  'search': np.float64(-1.400646818506626),
#  'omggg': np.float64(-1.1129647460548462),
#  'boy': np.float64(0.2268095994301529),
#  'brb': np.float64(-0.014352457386735296),
#  'shor': np.float64(-0.7074996379466807),
#  'initi': np.float64(0.3911126507214284),
#  'indonesia': np.float64(0.6787947231732101),
#  'chweina': np.float64(0.6787947231732101),
#  'walnut': np.float64(-0.7074996379466807),
#  '.\n.\n.': np.float64(0.6787947231732101),
#  'crackl': np.float64(-0.014352457386735296),
#  '911': np.float64(-0.7074996379466807),
#  'suuuper': np.float64(-0.7074996379466807),
#  'vin': np.float64(-0.7074996379466807),
#  'philippin': np.float64(1.0842598312813738),
#  'agil': np.float64(0.6787947231732101),
#  'champagn': np.float64(-0.014352457386735296),
#  'umair': np.float64(0.6787947231732101),
#  'outdat': np.float64(-0.7074996379466807),
#  'case': np.float64(-0.16850313721399424),
#  'tut': np.float64(-0.7074996379466807),
#  'impair': np.float64(0.6787947231732101),
#  'lmaoo': np.float64(1.0842598312813738),
#  'realisticli': np.float64(0.6787947231732101),
#  'disappear': np.float64(-0.7074996379466807),
#  'jurass': np.float64(0.6787947231732101),
#  'coz': np.float64(-0.302034529838517),
#  'disneyinfin': np.float64(0.6787947231732101),
#  'umaga': np.float64(0.6787947231732101),
#  'pleas': np.float64(-1.104801435415684),
#  'documentari': np.float64(0.6787947231732101),
#  'kumbl': np.float64(-0.7074996379466807),
#  'got': np.float64(-0.46476895335716684),
#  'fabul': np.float64(1.5950854550473643),
#  'himach': np.float64(0.6787947231732101),
#  'zipper': np.float64(-0.7074996379466807),
#  'comic': np.float64(-0.7074996379466807),
#  'blamehoney': np.float64(-0.7074996379466807),
#  'phone': np.float64(-0.47697597933484825),
#  'whimper': np.float64(-0.7074996379466807),
#  'dental': np.float64(-0.7074996379466807),
#  'chilton': np.float64(-0.7074996379466807),
#  'namecheck': np.float64(-0.7074996379466807),
#  'med': np.float64(-0.7074996379466807),
#  'excel': np.float64(1.7774070118413192),
#  'infrastructur': np.float64(-1.1129647460548462),
#  'swallow': np.float64(-0.7074996379466807),
#  'harsh': np.float64(-0.7074996379466807),
#  'dong': np.float64(-1.400646818506626),
#  'outdoor': np.float64(0.6787947231732101),
#  'din': np.float64(-0.014352457386735296),
#  'laser-lik': np.float64(0.6787947231732101),
#  'watchdog': np.float64(-0.7074996379466807),
#  'otter': np.float64(-0.7074996379466807),
#  'weebli': np.float64(0.6787947231732101),
#  'mca': np.float64(0.6787947231732101),
#  'videogam': np.float64(0.6787947231732101),
#  'beg': np.float64(-0.014352457386737072),
#  'pie': np.float64(0.6787947231732101),
#  'moo': np.float64(1.0842598312813738),
#  'torrentialrain': np.float64(-0.7074996379466807),
#  'sandra': np.float64(-0.7074996379466807),
#  'newwin': np.float64(-0.7074996379466807),
#  'breaktym': np.float64(0.6787947231732101),
#  'scream': np.float64(0.3911126507214284),
#  'debat': np.float64(1.0842598312813738),
#  'snap': np.float64(0.2733296150650446),
#  '4leader': np.float64(0.6787947231732101),
#  'hierro': np.float64(-0.7074996379466807),
#  'poster': np.float64(1.0842598312813738),
#  'lu': np.float64(-0.014352457386735296),
#  'els': np.float64(0.5734342075153833),
#  'ylona': np.float64(-0.7074996379466807),
#  'might': np.float64(0.6787947231732101),
#  'fraud': np.float64(-0.7074996379466807),
#  'twist': np.float64(-0.014352457386735296),
#  'emeg': np.float64(-0.7074996379466807),
#  'norapowel': np.float64(0.6787947231732101),
#  'insta': np.float64(-0.7074996379466807),
#  'firmansyahbl': np.float64(0.6787947231732101),
#  'huhuhuhu': np.float64(-0.7074996379466807),
#  'lil': np.float64(-0.48435608663247187),
#  'nite': np.float64(0.6787947231732101),
#  'sf': np.float64(-0.4198175654949008),
#  'jest': np.float64(-0.7074996379466807),
#  'unless': np.float64(-0.302034529838517),
#  'mufc': np.float64(-0.7074996379466807),
#  'jo': np.float64(0.6787947231732101),
#  'hide': np.float64(-0.302034529838517),
#  'disturb': np.float64(-0.7074996379466807),
#  'except': np.float64(-0.7074996379466825),
#  'panem': np.float64(-0.7074996379466807),
#  '1': np.float64(1.1487983524189458),
#  'kurta': np.float64(1.3719419037331555),
#  'expand': np.float64(1.0842598312813738),
#  'ami': np.float64(0.4964731663792534),
#  'uniqu': np.float64(0.3911126507214284),
#  'bissmillah': np.float64(0.6787947231732101),
#  'thta': np.float64(0.6787947231732101),
#  'dunt': np.float64(-0.7074996379466807),
#  'sleepov': np.float64(-0.7074996379466807),
#  'booti': np.float64(-0.014352457386737072),
#  '11.00': np.float64(-0.7074996379466807),
#  'hill': np.float64(0.9019382744874189),
#  'un': np.float64(-0.014352457386735296),
#  'tempt': np.float64(-1.1129647460548462),
#  'symphoni': np.float64(-0.7074996379466807),
#  'talent': np.float64(0.4964731663792534),
#  'bite': np.float64(-0.7074996379466807),
#  'selfiee': np.float64(0.6787947231732101),
#  'yesss': np.float64(1.7774070118413192),
#  'tweenie_fox': np.float64(0.6787947231732101),
#  'chocolatey': np.float64(0.6787947231732101),
#  'babysit': np.float64(-0.7074996379466807),
#  'ode': np.float64(-0.7074996379466807),
#  'disagre': np.float64(0.6787947231732101),
#  'gain': np.float64(1.3719419037331555),
#  'januari': np.float64(0.6787947231732101),
#  'parijat': np.float64(-0.7074996379466807),
#  '1190': np.float64(-0.7074996379466807),
#  'img': np.float64(0.6787947231732101),
#  'plss': np.float64(-0.7074996379466807),
#  'whitey': np.float64(0.6787947231732101),
#  'border': np.float64(0.6787947231732101),
#  'amazon': np.float64(-0.9306431892608913),
#  'pampanga': np.float64(0.6787947231732101),
#  'por': np.float64(-0.7074996379466807),
#  'write': np.float64(0.2733296150650446),
#  'kiss': np.float64(-0.2374960087009459),
#  'ruin': np.float64(-0.6204882609570515),
#  '63': np.float64(0.6787947231732101),
#  'line': np.float64(-0.14788385001125803),
#  'suk': np.float64(-1.1129647460548462),
#  'hun': np.float64(-0.302034529838517),
#  'messi': np.float64(-0.7074996379466807),
#  'notion': np.float64(-0.014352457386735296),
#  'vein': np.float64(0.6787947231732101),
#  'dirti': np.float64(1.0842598312813738),
#  'saklap': np.float64(-0.7074996379466807),
#  '15th': np.float64(1.0842598312813738),
#  'murugan': np.float64(-0.7074996379466807),
#  'creat': np.float64(0.8329454030004673),
#  'filbarbarian': np.float64(0.6787947231732101),
#  'akon': np.float64(-0.7074996379466807),
#  'cornish': np.float64(0.6787947231732101),
#  'fenestoscop': np.float64(-0.7074996379466807),
#  'soggi': np.float64(-0.7074996379466807),
#  'mager': np.float64(-0.7074996379466807),
#  'vii': np.float64(0.6787947231732101),
#  'ti5': np.float64(-0.014352457386735296),
#  'biker': np.float64(0.6787947231732101),
#  'jannatul': np.float64(-0.7074996379466807),
#  'plusmil': np.float64(0.6787947231732101),
#  'bracelet': np.float64(-0.014352457386737072),
#  '3-0': np.float64(-0.7074996379466807),
#  'christen': np.float64(0.6787947231732101),
#  'pano': np.float64(-0.7074996379466807),
#  'you': np.float64(0.6787947231732101),
#  'date': np.float64(0.4376326663563219),
#  'migrain': np.float64(-1.1129647460548462),
#  'struck': np.float64(-0.7074996379466807),
#  'nia': np.float64(-0.7074996379466807),
#  'knowww': np.float64(-0.7074996379466807),
#  'us-iran': np.float64(-0.7074996379466807),
#  'judo': np.float64(0.6787947231732101),
#  'colombia': np.float64(-0.7074996379466807),
#  'sting': np.float64(-0.7074996379466807),
#  'uniteblu': np.float64(-2.412247730185106),
#  'leo': np.float64(0.6787947231732101),
#  'bee': np.float64(-0.7074996379466807),
#  'cannot': np.float64(-0.2374960087009459),
#  "lady'": np.float64(0.6787947231732101),
#  'rear-end': np.float64(-0.7074996379466807),
#  'nicest': np.float64(-0.7074996379466807),
#  'box': np.float64(-0.7074996379466825),
#  'tellanoldjokeday': np.float64(0.6787947231732101),
#  'snot': np.float64(-0.7074996379466807),
#  '😞': np.float64(-1.1129647460548462),
#  'samee': np.float64(0.6787947231732101),
#  'forget': np.float64(1.0271014174414246),
#  'whomosexu': np.float64(0.6787947231732101),
#  'weekli': np.float64(0.3911126507214284),
#  'intellectu': np.float64(1.0842598312813738),
#  'faster': np.float64(0.3911126507214284),
#  'zonzofox': np.float64(1.0842598312813738),
#  'lizaminnelli': np.float64(0.6787947231732101),
#  'mammoth': np.float64(-0.7074996379466807),
#  'dun': np.float64(0.6787947231732101),
#  'sosweet': np.float64(0.6787947231732101),
#  'mosqu': np.float64(-0.7074996379466807),
#  'bahari': np.float64(0.6787947231732101),
#  'amargolonnard': np.float64(-0.7074996379466807),
#  'bebravetoday': np.float64(0.6787947231732101),
#  'lovey': np.float64(-0.7074996379466807),
#  'deadlin': np.float64(-0.7074996379466807),
#  'leeteuk': np.float64(0.6787947231732101),
#  'wendi': np.float64(1.0842598312813738),
#  'iamca': np.float64(0.6787947231732101),
#  'preorder': np.float64(0.6787947231732101),
#  'oshieer': np.float64(0.6787947231732101),
#  '💫': np.float64(-0.7074996379466807),
#  'dear': np.float64(0.2733296150650446),
#  'renew': np.float64(0.6787947231732101),
#  'despit': np.float64(-0.014352457386737072),
#  'aunti': np.float64(0.6787947231732101),
#  'imposs': np.float64(-1.6237903698208367),
#  'sponsorship': np.float64(0.6787947231732101),
#  'hairi': np.float64(-0.7074996379466807),
#  'ip': np.float64(-0.014352457386735296),
#  'inspit': np.float64(0.6787947231732101),
#  'sali': np.float64(0.6787947231732101),
#  'bruno': np.float64(-0.7074996379466807),
#  'alvadhaau': np.float64(-0.7074996379466807),
#  'emul': np.float64(0.6787947231732101),
#  'full': np.float64(0.39111265072142753),
#  'everytim': np.float64(1.3719419037331555),
#  'nagato': np.float64(0.6787947231732101),
#  'diner': np.float64(-0.7074996379466807),
#  'thank': np.float64(1.6913521150776463),
#  'promo': np.float64(0.3911126507214284),
#  'huhu': np.float64(-1.336108297369055),
#  'misspelt': np.float64(-0.7074996379466807),
#  'label': np.float64(0.6787947231732101),
#  'tl': np.float64(-1.400646818506626),
#  'rumpi': np.float64(-0.7074996379466807),
#  'brotherhood': np.float64(0.6787947231732101),
#  '40mm': np.float64(0.6787947231732101),
#  'u21': np.float64(0.6787947231732101),
#  'seed': np.float64(1.3719419037331555),
#  'happybirthdayemilybett': np.float64(0.6787947231732101),
#  'margo': np.float64(-0.7074996379466807),
#  '1st': np.float64(-0.7074996379466807),
#  'leak': np.float64(-0.7074996379466807),
#  'sri': np.float64(-0.7074996379466807),
#  'march': np.float64(-0.014352457386735296),
#  'pass': np.float64(-0.1814065420499018),
#  'swollen': np.float64(-0.7074996379466807),
#  'cosi': np.float64(0.6787947231732101),
#  'meydan': np.float64(-0.7074996379466807),
#  'forev': np.float64(-0.302034529838517),
#  'tab': np.float64(-1.1129647460548462),
#  'mixtap': np.float64(-1.1129647460548462),
#  'privaci': np.float64(0.6787947231732101),
#  'tommarow': np.float64(0.6787947231732101),
#  'teh': np.float64(0.6787947231732101),
#  'wan': np.float64(-0.014352457386735296),
#  'aaahh': np.float64(-0.7074996379466807),
#  'israel': np.float64(-0.7074996379466807),
#  'headphon': np.float64(-0.7074996379466807),
#  'iero': np.float64(0.6787947231732101),
#  'superb': np.float64(0.6787947231732101),
#  'fond': np.float64(0.6787947231732101),
#  'bruce': np.float64(-0.014352457386735296),
#  '☺': np.float64(-0.014352457386737072),
#  'tbh': np.float64(-0.787542345620218),
#  'dudafti': np.float64(0.6787947231732101),
#  'kink': np.float64(-0.7074996379466807),
#  'disvirgin': np.float64(-0.7074996379466807),
#  'ladyposs': np.float64(0.6787947231732101),
#  '24': np.float64(-0.9306431892608913),
#  'marula': np.float64(0.6787947231732101),
#  'fool': np.float64(-0.7074996379466807),
#  'beastmod': np.float64(-0.7074996379466807),
#  'vantast': np.float64(0.6787947231732101),
#  'san': np.float64(-0.4198175654949008),
#  'nice': np.float64(1.3719419037331546),
#  '4like': np.float64(-1.6237903698208367),
#  "beach'": np.float64(0.6787947231732101),
#  'baz': np.float64(0.6787947231732101),
#  'hk': np.float64(-0.014352457386735296),
#  'heart': np.float64(-1.2039365242605724),
#  'isaac': np.float64(0.6787947231732101),
#  'slide': np.float64(-0.7074996379466807),
#  'visa': np.float64(0.6787947231732101),
#  'die-of': np.float64(-0.7074996379466807),
#  'clutch': np.float64(-0.014352457386735296),
#  'youtu.be/2_gpctsojkw': np.float64(-0.7074996379466807),
#  'coveral': np.float64(-0.7074996379466807),
#  'dime': np.float64(0.6787947231732101),
#  'delet': np.float64(-1.8061119266147916),
#  'pain': np.float64(-0.7074996379466807),
#  'lotion': np.float64(0.6787947231732101),
#  'stafford': np.float64(-0.7074996379466807),
#  'socialreward': np.float64(-0.7074996379466807),
#  'wt': np.float64(-0.7074996379466807),
#  'nathanielhinanakit': np.float64(-0.7074996379466807),
#  'x27': np.float64(0.6787947231732101),
#  'along': np.float64(0.3911126507214284),
#  'melbournetrip': np.float64(0.6787947231732101),
#  'graze': np.float64(0.6787947231732101),
#  'ayex': np.float64(-0.7074996379466807),
#  'typa': np.float64(-1.400646818506626),
#  'glaze': np.float64(0.6787947231732101),
#  'du': np.float64(-0.7074996379466807),
#  'numb': np.float64(-0.7074996379466807),
#  'overwhelm': np.float64(-0.014352457386735296),
#  'pl': np.float64(-1.364279174335751),
#  'pamer': np.float64(0.6787947231732101),
#  'aki': np.float64(0.6787947231732101),
#  'swifti': np.float64(-0.7074996379466807),
#  'newyork': np.float64(0.6787947231732101),
#  'knit': np.float64(0.6787947231732101),
#  'comp': np.float64(0.6787947231732101),
#  'front': np.float64(-0.573968245322158),
#  'troll': np.float64(0.6787947231732101),
#  "shamuon'": np.float64(-0.7074996379466807),
#  'make': np.float64(-0.2625320868622705),
#  'cala': np.float64(0.6787947231732101),
#  'madam': np.float64(0.6787947231732101),
#  'newbi': np.float64(-0.7074996379466807),
#  'naeun': np.float64(-0.7074996379466807),
#  'sunway': np.float64(-0.7074996379466807),
#  '♥': np.float64(-0.4198175654948999),
#  'wooden': np.float64(-0.7074996379466807),
#  'guy': np.float64(0.04882644423479565),
#  'etl': np.float64(0.6787947231732101),
#  'sumer': np.float64(-0.7074996379466807),
#  'savag': np.float64(0.6787947231732101),
#  'thehungergam': np.float64(0.6787947231732101),
#  'occas': np.float64(0.6787947231732101),
#  'gem': np.float64(1.0842598312813738),
#  'obv': np.float64(0.6787947231732101),
#  'cikaaa': np.float64(0.6787947231732101),
#  'item': np.float64(0.3911126507214284),
#  'becho': np.float64(-0.7074996379466807),
#  'happybirthday': np.float64(0.6787947231732101),
#  'william': np.float64(-0.7074996379466807),
#  'bugger': np.float64(-0.7074996379466807),
#  'sometim': np.float64(-0.302034529838517),
#  'monfil': np.float64(0.6787947231732101),
#  'input': np.float64(-0.7074996379466807),
#  'rita': np.float64(1.0842598312813738),
#  'butterfli': np.float64(0.6787947231732101),
#  'oval': np.float64(0.6787947231732101),
#  'carri': np.float64(1.0842598312813738),
#  '1033': np.float64(0.6787947231732101),
#  'bein': np.float64(-0.7074996379466807),
#  'pool': np.float64(0.3911126507214284),
#  'havent': np.float64(-0.6021391222888557),
#  'batch': np.float64(0.6787947231732101),
#  'diz': np.float64(-0.7074996379466807),
#  'acn': np.float64(-1.1129647460548462),
#  'fuse': np.float64(-0.7074996379466807),
#  'zach': np.float64(0.6787947231732101),
#  'catspj': np.float64(0.6787947231732101),
#  'novel': np.float64(0.6787947231732101),
#  'leader': np.float64(0.6787947231732101),
#  'cara': np.float64(-0.7074996379466807),
#  'nanci': np.float64(0.6787947231732101),
#  'zehr': np.float64(-0.7074996379466807),
#  'vacant': np.float64(0.6787947231732101),
#  'dayz': np.float64(0.6787947231732101),
#  'report': np.float64(-0.7074996379466807),
#  'row': np.float64(-1.1129647460548462),
#  'soak': np.float64(-0.7074996379466807),
#  'boob': np.float64(-0.4198175654949008),
#  'thermal': np.float64(1.5950854550473643),
#  'stroke': np.float64(0.6787947231732101),
#  'standwdik': np.float64(0.6787947231732101),
#  'instagram': np.float64(0.3911126507214284),
#  '76x': np.float64(0.6787947231732101),
#  'alunageorg': np.float64(0.6787947231732101),
#  'budapestgp': np.float64(0.6787947231732101),
#  'crosss': np.float64(-0.7074996379466807),
#  'teenag': np.float64(-0.4198175654949008),
#  'vip': np.float64(-0.014352457386735296),
#  'ass': np.float64(-1.51842985416301),
#  'weav': np.float64(-1.1129647460548462),
#  'heathrow': np.float64(-0.7074996379466807),
#  "why'd": np.float64(0.6787947231732101),
#  'pearson': np.float64(0.6787947231732101),
#  'batalladelosgallo': np.float64(-1.1129647460548462),
#  'coff': np.float64(1.0842598312813738),
#  'mpoint': np.float64(-0.7074996379466807),
#  'clich': np.float64(-0.7074996379466807),
#  'audit': np.float64(-0.7074996379466807),
#  'wwat': np.float64(1.0842598312813738),
#  'deennya': np.float64(0.6787947231732101),
#  'lake': np.float64(0.6787947231732101),
#  'killua': np.float64(0.6787947231732101),
#  'auspost': np.float64(0.6787947231732101),
#  'agonis': np.float64(-0.7074996379466807),
#  'kelli': np.float64(0.6787947231732101),
#  'swipe': np.float64(-0.7074996379466807),
#  'blacklivesmatt': np.float64(-0.7074996379466807),
#  'bbmme': np.float64(1.3719419037331555),
#  'medicin': np.float64(-1.400646818506626),
#  'twitch': np.float64(2.065089084293101),
#  'brianazabrocki': np.float64(0.6787947231732101),
#  'yahoo': np.float64(-1.1129647460548462),
#  "cinema'": np.float64(0.6787947231732101),
#  'third': np.float64(-0.014352457386735296),
#  'suger': np.float64(-0.7074996379466807),
#  'justin': np.float64(-0.014352457386737072),
#  'helppp': np.float64(-1.1129647460548462),
#  'size': np.float64(-0.573968245322158),
#  '1:30': np.float64(0.6787947231732101),
#  'brook': np.float64(-0.7074996379466807),
#  'firebal': np.float64(0.6787947231732101),
#  'selway': np.float64(0.6787947231732101),
#  ...}

# %% [markdown]
# 5. Реалізувати функцію наївного баєсового класифікатора.
#
# Алгоритм:
# - Обробити твіт з допомогою process_tweet.
# - Встановити початкову ймовірність p = logprior.
# - Для кожного слова у твіті:
#     - Якщо слово є в словнику loglikelihood:
#         - Додати loglikelihood цього слова до p.
# - Повернути суму ймовірностей p.
#
# Приклад реалізації:

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    word_l = process_tweet(tweet)

    p = logprior

    for word in word_l:
        if word in loglikelihood:
            p += loglikelihood[word]

    return p

# %% [markdown]
# 6. Оцінити точність класифікатора на тестовому наборі даних.
#
# Алгоритм:
# - Для кожного твіту в тестовому наборі:
#     - Класифікувати твіт з допомогою naive_bayes_predict.
#     - Якщо ймовірність > 0, присвоїти твіту мітку 1, інакше 0.
#     - Додати передбачену мітку до списку.
# - Порахувати середню абсолютну похибку між передбаченими та справжніми мітками.
# - Обчислити точність як 1 - похибка.
#
# Приклад реалізації:

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    accuracy = 0

    y_hats = []
    for tweet in test_x:
        if naive_bayes_predict(tweet, logprior, loglikelihood) > 0:
            y_hat_i = 1
        else:
            y_hat_i = 0
        y_hats.append(y_hat_i)

    error = np.mean(np.absolute(y_hats - test_y))
    accuracy = 1 - error

    return accuracy

# %%
accuracy = test_naive_bayes(test_x, test_y, logprior, loglikelihood)

# %%
accuracy
# Out:
# np.float64(0.9955)

# %% [markdown]
# 7. Проаналізувати найбільш позитивні та негативні слова за співвідношенням їх частотностей.

# %% [markdown]
# Функція get_ratio обчислює відношення частотності слова для позитивного класу до негативного.
#
# Алгоритм get_ratio:
# - Ініціалізувати словник з ключами 'positive', 'negative', 'ratio' і значеннями 0.
# - Знайти кількість появ слова для позитивного класу з допомогою функції lookup і записати в 'positive'.
# - Знайти кількість появ слова для негативного класу і записати в 'negative'.
# - Обчислити відношення позитивної частотності до негативної і записати в 'ratio'.

# %%
def get_ratio(freqs, word):
    pos_neg_ratio = {'positive': 0, 'negative': 0, 'ratio': 0.0}

    pos_neg_ratio['positive'] = lookup(freqs, word, 1)

    pos_neg_ratio['negative'] = lookup(freqs, word, 0)

    pos_neg_ratio['ratio'] = (pos_neg_ratio['positive'] + 1) / (pos_neg_ratio['negative'] + 1)

    return pos_neg_ratio

def lookup(freqs, word, label):
    n = 0

    pair = (word, label)
    if (pair in freqs):
        n = freqs[pair]

    return n

# %%
get_ratio(freqs, 'luck')
# Out:
# {'positive': 26, 'negative': 5, 'ratio': 4.5}

# %% [markdown]
# Функція get_words_by_threshold повертає слова, які мають відношення частотностей, більше або менше заданого порогу, залежно від мітки класу.
#
# Алгоритм get_words_by_threshold:
# - Ініціалізувати порожній словник word_list.
# - Для кожного слова у словнику частотностей:
#     - Обчислити відношення частотностей з допомогою get_ratio.
#     - Якщо мітка = 1 і відношення >= поріг, додати слово і його pos_neg_ratio до word_list.
#     - Якщо мітка = 0 і відношення <= поріг, додати слово і його pos_neg_ratio до word_list.

# %%
def get_words_by_threshold(freqs, label, threshold):
    word_list = {}

    for key in freqs.keys():
        word, _ = key

        pos_neg_ratio = get_ratio(freqs, word)

        if label == 1 and pos_neg_ratio['ratio'] >= threshold:
            word_list[word] = pos_neg_ratio
        elif label == 0 and pos_neg_ratio['ratio'] <= threshold:
            word_list[word] = pos_neg_ratio

    return word_list

# %%
get_words_by_threshold(freqs, 0, 0.2)
# Out:
# {'miss': {'positive': 17, 'negative': 239, 'ratio': 0.075},
#  'hurt': {'positive': 4, 'negative': 33, 'ratio': 0.14705882352941177},
#  'sorri': {'positive': 13, 'negative': 118, 'ratio': 0.11764705882352941},
#  'cri': {'positive': 7, 'negative': 39, 'ratio': 0.2},
#  'tire': {'positive': 5, 'negative': 37, 'ratio': 0.15789473684210525},
#  'sadli': {'positive': 1, 'negative': 11, 'ratio': 0.16666666666666666},
#  'sad': {'positive': 5, 'negative': 100, 'ratio': 0.0594059405940594},
#  'ugh': {'positive': 1, 'negative': 23, 'ratio': 0.08333333333333333},
#  'leed': {'positive': 1, 'negative': 9, 'ratio': 0.2},
#  'sick': {'positive': 1, 'negative': 32, 'ratio': 0.06060606060606061},
#  'bc': {'positive': 7, 'negative': 39, 'ratio': 0.2},
#  '😭': {'positive': 2, 'negative': 23, 'ratio': 0.125},
#  'disappoint': {'positive': 1, 'negative': 11, 'ratio': 0.16666666666666666},
#  'poor': {'positive': 3, 'negative': 24, 'ratio': 0.16},
#  '�': {'positive': 2, 'negative': 21, 'ratio': 0.13636363636363635},
#  'kikchat': {'positive': 1, 'negative': 9, 'ratio': 0.2},
#  'damn': {'positive': 3, 'negative': 22, 'ratio': 0.17391304347826086},
#  'upset': {'positive': 1, 'negative': 10, 'ratio': 0.18181818181818182},
#  ':(': {'positive': 1, 'negative': 3675, 'ratio': 0.000544069640914037},
#  'unfortun': {'positive': 2, 'negative': 14, 'ratio': 0.2},
#  'cold': {'positive': 1, 'negative': 13, 'ratio': 0.14285714285714285},
#  'x15': {'positive': 1, 'negative': 35, 'ratio': 0.05555555555555555},
#  'aw': {'positive': 2, 'negative': 30, 'ratio': 0.0967741935483871},
#  'shame': {'positive': 1, 'negative': 19, 'ratio': 0.1},
#  'longer': {'positive': 1, 'negative': 9, 'ratio': 0.2},
#  'kikhorni': {'positive': 1, 'negative': 10, 'ratio': 0.18181818181818182},
#  'hornykik': {'positive': 2, 'negative': 14, 'ratio': 0.2},
#  'didnt': {'positive': 1, 'negative': 19, 'ratio': 0.1},
#  'ignor': {'positive': 1, 'negative': 15, 'ratio': 0.125},
#  'scare': {'positive': 1, 'negative': 13, 'ratio': 0.14285714285714285},
#  ':-(': {'positive': 0, 'negative': 386, 'ratio': 0.002583979328165375},
#  'digit': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'lone': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  '😩': {'positive': 0, 'negative': 11, 'ratio': 0.08333333333333333},
#  'climatechang': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'uniteblu': {'positive': 0, 'negative': 10, 'ratio': 0.09090909090909091},
#  'tcot': {'positive': 0, 'negative': 9, 'ratio': 0.1},
#  'boss': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'older': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'encor': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  '4thwin': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'zayniscomingbackonjuli': {'positive': 0, 'negative': 19, 'ratio': 0.05},
#  '26': {'positive': 0, 'negative': 20, 'ratio': 0.047619047619047616},
#  'netflix': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'funer': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'brace': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'whyyi': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  'egg': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'badli': {'positive': 0, 'negative': 9, 'ratio': 0.1},
#  '>:(': {'positive': 0, 'negative': 43, 'ratio': 0.022727272727272728},
#  'hahah': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'ive': {'positive': 0, 'negative': 10, 'ratio': 0.09090909090909091},
#  'lost': {'positive': 0, 'negative': 19, 'ratio': 0.05},
#  'reject': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  'idk': {'positive': 0, 'negative': 17, 'ratio': 0.05555555555555555},
#  'anybodi': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'belgium': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'delph': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'pray': {'positive': 0, 'negative': 12, 'ratio': 0.07692307692307693},
#  'across': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'imposs': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'nooo': {'positive': 0, 'negative': 10, 'ratio': 0.09090909090909091},
#  'snapchatm': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'concept': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'rli': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'expens': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  ":'(": {'positive': 0, 'negative': 12, 'ratio': 0.07692307692307693},
#  'crash': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  'vehicl': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'camp': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'discrimin': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'foot': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'f': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'beta': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'sold': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'cancel': {'positive': 0, 'negative': 10, 'ratio': 0.09090909090909091},
#  'mess': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'delet': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'hay': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'inact': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  'unfair': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'esp': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'nose': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'afford': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'schedul': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'forehead': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'paid': {'positive': 0, 'negative': 8, 'ratio': 0.1111111111111111},
#  'nightmar': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'straight': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'drag': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'serious': {'positive': 0, 'negative': 9, 'ratio': 0.1},
#  'kiksex': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'alon': {'positive': 0, 'negative': 12, 'ratio': 0.07692307692307693},
#  'frustrat': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'sock': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'camsex': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'gut': {'positive': 0, 'negative': 10, 'ratio': 0.09090909090909091},
#  'sunggyu': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'injur': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  'stadium': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'sexual': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'cinema': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'sandrabland': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'justinbieb': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  ';(': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'deactiv': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'poorli': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'tummi': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'isco': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'likeforlik': {'positive': 0, 'negative': 7, 'ratio': 0.125},
#  'ubericecream': {'positive': 0, 'negative': 13, 'ratio': 0.07142857142857142},
#  '＠': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'maverickgam': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'repair': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'network': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'damag': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'fra': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'th': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'chair': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'throat': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'depress': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'grabe': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'disgust': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  '😢': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'struggl': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'headach': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'stomach': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  'upvot': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  '😔': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  'grumpi': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'bakit': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  '♛': {'positive': 0, 'negative': 210, 'ratio': 0.004739336492890996},
#  '》': {'positive': 0, 'negative': 210, 'ratio': 0.004739336492890996},
#  'beli̇ev': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'wi̇ll': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'justi̇n': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'ｓｅｅ': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'ｍｅ': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'jackson': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'sophi': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  '4like': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'sandwich': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'sudden': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'gyu': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'locat': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'chri': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'ed': {'positive': 0, 'negative': 5, 'ratio': 0.16666666666666666},
#  'niall': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'd:': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285},
#  'tammirossm': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'error': {'positive': 0, 'negative': 4, 'ratio': 0.2},
#  'boyfriend': {'positive': 0, 'negative': 6, 'ratio': 0.14285714285714285}}

# %% [markdown]
# 8. Проаналізувати помилки класифікації.
#
# Алгоритм:
# - Для кожної пари (твіт, справжня мітка) з тестового набору:
#     - Класифікувати твіт та отримати передбачену ймовірність.
#     - Якщо справжня мітка не збігається з передбаченою:
#         - Вивести справжню мітку, передбачену мітку і оброблений твіт.

# %%
print('Truth Predicted Tweet')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Truth Predicted Tweet
# 1	0.00	b'truli later move know queen bee upward bound movingonup'
# 1	0.00	b'new report talk burn calori cold work harder warm feel better weather :p'
# 1	0.00	b'harri niall 94 harri born ik stupid wanna chang :d'
# 1	0.00	b'park get sunlight'
# 1	0.00	b'uff itna miss karhi thi ap :p'
# 0	1.00	b'hello info possibl interest jonatha close join beti :( great'
# 0	1.00	b'u prob fun david'
# 0	1.00	b'pat jay'
# 0	1.00	b'sr financi analyst expedia inc bellevu wa financ expediajob job job hire'

# %% [markdown]
# 9. Протестувати класифікатор на власному твіті. Розгорніть відповідну сторінку на GitHub.
# 10. Завантажити код та результати на GitHub, надати посилання на них та сторінку у Moodle.

# %%
my_tweet = 'I am happy because I am sad'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# -0.7027547407463546

# %%
import json

# Передбачається, що модель вже навчена і наявні logprior та loglikelihood
data = {
    'logprior': logprior,
    'loglikelihood': loglikelihood
}

# Збереження у файлі JSON
with open('naive_bayes_model.json', 'w') as outfile:
    json.dump(data, outfile)
